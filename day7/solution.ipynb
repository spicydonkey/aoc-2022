# %%
filename = "input.txt"

# %%
from typing import Optional

class Directory:
    def __init__(self, name: str, parent: Optional["Directory"] = None):
        self.name = name
        self.parent = parent
        if parent is not None:
            parent.contents.append(self)
        self.contents: dict[str: int | dict] = {}

# %%
with open(filename, "r") as file:    
    filesystem = {}  # the root directory
    cwd = None  # current working directory
    dir_stack = []  # stack of directories visited
    for line in file:
        # parse this line
        # print(line.strip())
        tokens = line.strip().split()
        # print(tokens)
        
        if tokens[0] == "$":
            if tokens[1] == "cd":
                # update the current working directory
                if tokens[2] == "/":
                    cwd = filesystem
                elif tokens[2] == "..":
                    cwd = dir_stack.pop()
                else:
                    dir_stack.append(cwd)
                    cwd = cwd[tokens[2]]
            elif tokens[1] == "ls":
                # parsing control will be done purely by the 0th token
                pass
            else:
                raise ValueError(f"Unexpected command encountered: {line}")
        # return from `$ ls`
        else:
            # append this file/directory to cwd
            if tokens[0] == "dir":
                cwd[tokens[1]] = {}
            else:
                cwd[tokens[1]] = int(tokens[0])

# %%
from pprint import pprint 
pprint(filesystem)
# Out:
# {'chvtw.czb': 53302,
#  'dwhl.nrn': 240038,
#  'dwhl.vvb': 124868,
#  'fml': {'bztjtqg': {'dwhl': {'fqdzv': {'mfprqmdp.pnl': 140953},
#                               'mmrplb.ncb': 198583,
#                               'qmdjhrsg': 42601,
#                               'rnmsmcqn.cwf': 68484,
#                               'wlfprc': {'swjgs.glp': 180121}},
#                      'lwtrqrqq': {'swjgs.glp': 224392},
#                      'nsdgz': {'chvtw.wzb': 5704,
#                                'gppbtqsw.mrr': 158254,
#                                'pltnst.mnt': 192803,
#                                'pst.njs': 265646,
#                                'qzdb': {'jcjcv': 171982, 'tfr.hlv': 125788}},
#                      'qlsr': 105281},
#          'crgzcmrt.jlr': 176916,
#          'gpnmqlr.rdb': 199024,
#          'lwpbbb': {'chvtw': {'mfprqmdp.pnl': 67998},
#                     'dtgbns.jfw': 88879,
#                     'fgfm': {'mfprqmdp.pnl': 85968},
#                     'nsdgz': {'pfwzjm.wbv': 171874, 'vdpnmst.wjm': 110070},
#                     'wlfprc.bhp': 216019},
#          'nsdgz': {'cqwh': {'bbpbg.sch': 220212,
#                             'dwhl': {'hfhlcjp.mtn': 51966,
#                                      'hhflcsql.pns': 23657,
#                                      'mwbgzn.fpn': 241753,
#                                      'srdgnb.zbj': 247935},
#                             'nsdgz.fcc': 203595,
#                             'nwjds': 123921,
#                             'sqg.dpb': 145468,
#                             'wvqphtff.stc': 199052},
#                    'dwhl.clh': 33973,
#                    'rdcmr': {'crgzcmrt.jlr': 215436, 'ndwd.drq': 116617},
#                    'sfrlrc.jtj': 140633,
#                    'stqhwh': {'cfmcj.plz': 28083,
#                               'chvtw': {'lspn': 120506, 'mfprqmdp.pnl': 214538},
#                               'hwf.wzr': 229939,
#                               'twfztmq': {'mbsrnbww': 231371},
#                               'vdpnmst.mcb': 219525,
#                               'wlfprc': {'dncq': {'swjgs.glp': 40876},
#                                          'fmqzns': {'chvtw.bhw': 23604}}},
#                    'vdpnmst.wqp': 24695,
#                    'wlfprc.dcf': 222421,
#                    'zfq': 225333},
#          'sfrlrc.jtj': 186077},
#  'jbgpgvj': {'crgzcmrt.jlr': 121937},
#  'qjphltd': {'chvtw': 85066,
#              'dwhl': {'cgrdfzc': {'ffzd': 145237,
#                                   'jqwgwcm': {'nsdgz.zdf': 115858},
#                                   'sztrgnwr.gqw': 72905,
#                                   'vdpqccdl.ddc': 58294},
#                       'chvtw.bfz': 197650,
#                       'dwhl.vww': 109566,
#                       'jgzjzvh': {'chvtw': {'zmwmcgcr': {'wjq': {'rbg.plr': 121465}}}},
#                       'sfsz': 80828,
#                       'vdpnmst.fmz': 154910,
#                       'zfrpc': {'cqv': {'vdpnmst': {'qsvf': 170492,
#                                                     'sfrlrc.jtj': 273024}},
#                                 'llwsnsd': {'dwhl.shp': 42903,
#                                             'fvwwghsb.dll': 179054,
#                                             'glhdqhf': {'pzll.cjc': 70524,
#                                                         'wlfprc.bns': 29836},
#                                             'wblwwf': {'jcfss': 209990},
#                                             'wlfprc': {'djqs.gqb': 97159},
#                                             'zrjzmj': {'fwrpcrbg.pvg': 164830,
#                                                        'vszfdj': 83144}},
#                                 'qrmg': {'nsdgz.sjw': 42025,
#                                          'swjgs.glp': 114620,
#                                          'tgptmhz.zch': 269872}}},
#              'fcqfgnvh': {'gbbfpz.rjv': 126854,
#                           'gbzslwz': {'njzvwjh': {'lvsjfvll.bfc': 44070}},
#                           'nsdgz': {'cmfz': {'ncshvdst': 37680},
#                                     'fztsf.lvz': 116103,
#                                     'mfprqmdp.pnl': 59406,
#                                     'wlfprc': {'jcvqttf.fqz': 273982}},
#                           'pmswh.nbz': 200981,
#                           'tdqwszvc': 45443,
#                           'vdpnmst.tbt': 227183},
#              'hbzf.wgc': 238098,
#              'ltm': {'mfprqmdp.pnl': 19761},
#              'mbbvp': {'wnv.vps': 12482, 'zlnlzzn': 46227},
#              'mfprqmdp.pnl': 118907,
#              'mgnl': {'bpc': {'chvtw': {'sfrlrc.jtj': 29411},
#                               'dwhl.ftj': 63061,
#                               'dzlv': {'vdpnmst.dtl': 140503},
#                               'gmp.fdd': 119367,
#                               'hdvdfnw': {'crgzcmrt.jlr': 36521,
#                                           'hsjb': {'swjgs.glp': 204248},
#                                           'mnl.scm': 231528,
#                                           'pczq': {'qzwd.tfn': 18842}},
#                               'nsdgz': {'bpgdn': {'wlfprc': 54889},
#                                         'nsdgz.vqs': 106092,
#                                         'pgbvnv': 71032,
#                                         'pthbb.znn': 47006,
#                                         'rll': {'shgfznp': 135900},
#                                         'wlfprc': {'dwhl': {'nvptwfp.qhh': 9122},
#                                                    'vddtj.jrh': 160547,
#                                                    'vdld.ndv': 114072,
#                                                    'wlfprc.lgg': 258527}},
#                               'pds': {'svq.gmz': 174820,
#                                       'zhpcdqnr.pmf': 133508},
#                               'sfrlrc.jtj': 48753,
#                               'vdpnmst.lnb': 186706,
#                               'wlfprc.dvf': 182938},
#                       'chvtw': {'vhspmg': {'flzpg': {'sdtgsjsd': 205811,
#                                                      'zbmsmzq.wwt': 262847}}},
#                       'dwhl': 240396,
#                       'hbbnwwh': 115971,
#                       'mfprqmdp.pnl': 33819,
#                       'nnbjb': 218670,
#                       'qwjp': {'crzqrz': {'srdgnb.zbj': 202759},
#                                'gwwrhjh': {'lvnsvm': {'tdrrztrn.rfb': 191751}},
#                                'mfprqmdp.pnl': 232315,
#                                'nsdgz': {'chvtw.gzr': 273767,
#                                          'pww.qgb': 244356},
#                                'qfsds.rhh': 248778,
#                                'vdpnmst.qgj': 252980},
#                       'tmhp.jst': 107343,
#                       'vfrbjgdm': {'chvtw': {'bfwl': {'frrsl': {'btzft.qdc': 164016},
#                                                       'sch': 1168,
#                                                       'vnzvmpmg': {'hfnjf': {'dqts.pgp': 267448}},
#                                                       'wlfprc': {'hsbg': {'cmdshfgh': 191520,
#                                                                           'crgzcmrt.jlr': 283887,
#                                                                           'dwhl': {'vdpnmst': 103303}},
#                                                                  'mgzvqhtr': {'dvlhwsj.gvl': 159296},
#                                                                  'nbbdv': {'hnv': {'wlfprc': 138102}},
#                                                                  'wflghrq.lws': 88560}},
#                                              'fvfmzg': {'ltzsj': 205962},
#                                              'mzmdjhjq': {'dwhl.dfd': 178012,
#                                                           'mmmlqppm.hcz': 155247,
#                                                           'npllz.ltb': 85643,
#                                                           'nsdgz.ngz': 122027,
#                                                           'wlfprc': {'rgsbqlw': 171189},
#                                                           'zrmt': {'dwhl': {'qbwm': 75018}}},
#                                              'srdgnb.zbj': 153152,
#                                              'stcfdsv.fjj': 239385,
#                                              'vdfw': {'ffsvhm': 77110,
#                                                       'lmplrbzc': {'mmf': {'sfrlrc.jtj': 127691}},
#                                                       'ttq': {'qwfvql': {'tbldv': {'mfprqmdp.pnl': 65603,
#                                                                                    'wdbprnm': 218354},
#                                                                          'vdpnmst': 276153},
#                                                               'rpgqwfb': 202107,
#                                                               'zhfg': {'wlfprc': {'dggm': {'chm': 197043},
#                                                                                   'mfprqmdp.pnl': 273082}}}},
#                                              'vdpnmst': 93411,
#                                              'wlfprc.hbq': 186283,
#                                              'wvgj': {'pcmbb.gwc': 163854}},
#                                    'cznw.mfc': 132015,
#                                    'fnw': {'bjnn.mqc': 84321,
#                                            'dmcbshg': {'fsh': {'cgstfrbl': {'vdpnmst': 227959}}},
#                                            'mdvt': {'mts': {'mfprqmdp.pnl': 242122},
#                                                     'pwrvqrjc': {'crgzcmrt.jlr': 40460,
#                                                                  'jzhvzrnv': 173816,
#                                                                  'swjgs.glp': 56851,
#                                                                  'wlfprc.cvr': 218509},
#                                                     'qwrh': {'lzwbvw.zvf': 240079},
#                                                     'sfrlrc.jtj': 52239}},
#                                    'gvddj': {'cgbpbw': {'bcbgqzj': {'vdpnmst.zvh': 199932},
#                                                         'dwhl': {'nsdgz.ttd': 116043},
#                                                         'nhtz': {'cthbt.tjj': 196534},
#                                                         'nlnbr': {'chvtw': {'sfrlrc.jtj': 119163,
#                                                                             'srdgnb.zbj': 226449},
#                                                                   'dwhl': {'dwhl': {'ptssf': 283831}},
#                                                                   'lhzhvn': 75467,
#                                                                   'ncmpwvrd': {'chvtw.hnh': 169547,
#                                                                                'wlfprc.pds': 142447},
#                                                                   'vdpnmst': {'jslgmcp.mmz': 276326},
#                                                                   'wlfprc': 160988}},
#                                              'chvtw.czc': 24565,
#                                              'nsdgz.mzj': 244373,
#                                              'srdgnb.zbj': 281443,
#                                              'swjgs.glp': 63755,
#                                              'vdpnmst': {'dwhl': 36500,
#                                                          'nwwhrf': 186159},
#                                              'wlfprc.nzd': 247101,
#                                              'zlh': {'chvtw.jgd': 245705}},
#                                    'jdzsng': {'dnzlvjr': 48648,
#                                               'fnzfrtrp.bll': 63253,
#                                               'zcgg.ldc': 9962},
#                                    'lmprp': 204950,
#                                    'nsdgz': {'cvvr': 188613},
#                                    'whd.qlv': 187795},
#                       'ztpggl': {'vbrtv': {'rswctm': 35655},
#                                  'vdpnmst': {'crgzcmrt.jlr': 143090,
#                                              'mfprqmdp.pnl': 242681,
#                                              'vdpnmst': 146639,
#                                              'vdpnmst.flr': 63563},
#                                  'vqm.zdj': 236782}},
#              'nhmqcpdl': {'dwhl': {'swjgs.glp': 253652},
#                           'nsdgz': {'crgzcmrt.jlr': 208378},
#                           'tgwtvm': {'jptp': {'chvtw.pgr': 103248,
#                                               'pvz': 65015},
#                                      'qdjl': {'chvtw.rzd': 149177},
#                                      'qngflrgr': {'drfl.jfq': 98041,
#                                                   'jjzqzmm': 238883}}},
#              'qtjcqtwt.vtn': 147292,
#              'tvplqllb': {'chvtw.mdn': 107011,
#                           'dwhl': 91988,
#                           'ftwz.fzj': 84875,
#                           'hpfr': {'bbgbnr': {'chvtw': 139093,
#                                               'crgzcmrt.jlr': 21309,
#                                               'nsjfgmrs': {'ppwm': {'ssl.fnd': 161664},
#                                                            'tvsqvsrf.plp': 167856,
#                                                            'vztfzgrd': {'fwjrgdbb': 213100}},
#                                               'qqt.mvb': 22977,
#                                               'srdgnb.zbj': 129496},
#                                    'dwhl': {'gtmgtq': 124522},
#                                    'fdpg': 131524,
#                                    'jvddlfsf': {'zpcc.wzt': 78145},
#                                    'mfprqmdp.pnl': 250910,
#                                    'qpl.qtm': 174858,
#                                    'sjncl.cjb': 271840,
#                                    'wlfprc': {'mfprqmdp.pnl': 143769}},
#                           'wdgzsg': {'chvtw.lpr': 209123,
#                                      'fqzjpnfb.lmd': 191060,
#                                      'gbcqgszh': {'crgzcmrt.jlr': 263162,
#                                                   'rddzmchb.fwr': 277604},
#                                      'jzhvmj': {'dnqs': 2388,
#                                                 'sfrlrc.jtj': 249647,
#                                                 'vcn': 276429,
#                                                 'wlfprc': {'mfprqmdp.pnl': 179811}},
#                                      'mfprqmdp.pnl': 17755,
#                                      'mvvltrs': {'bzq': 171792,
#                                                  'chvtw': {'crgzcmrt.jlr': 61085,
#                                                            'rbnvsbm': 72256,
#                                                            'wmwnpf': 154180},
#                                                  'crgzcmrt.jlr': 41358,
#                                                  'ddsjsbp': 86479,
#                                                  'dqvlqnn': {'chvtw.wcd': 42736},
#                                                  'srdgnb.zbj': 227156,
#                                                  'thwdjln': {'hdjvgpr': 114664,
#                                                              'pdsgj.tvr': 51273},
#                                                  'wjl': {'swjgs.glp': 49897},
#                                                  'wlfprc': {'chvtw': {'mfprqmdp.pnl': 84667},
#                                                             'zffqnb.plq': 222869}},
#                                      'wfmttzc.cdb': 204706,
#                                      'wlfprc': {'cjbjffhs.rlc': 180812,
#                                                 'dwhl': {'sbrdjv.cdt': 220631,
#                                                          'swjgs.glp': 24851},
#                                                 'rvgrjsps': {'wrlzz.nwn': 62849},
#                                                 'vql.lww': 229144,
#                                                 'wlfprc.ghn': 210367}}}},
#  'wlfprc': {'chvtw.vvq': 88598, 'mssqb.gwc': 222226, 'zjttbct.rft': 54178},
#  'zqvh': {'wmswcs.wcd': 124084},
#  'zzmgz': {'bbttfvt': 143006,
#            'vdpnmst': {'chvtw': {'chvtw.tmb': 57311, 'vdpnmst.wfl': 183900},
#                        'crgzcmrt.jlr': 107664,
#                        'dmp.hqm': 175290,
#                        'dwhl': {'lpdfsdb.cgj': 46475, 'vlhhrq.zld': 32915},
#                        'jtbh': {'chvtw.tmh': 255372,
#                                 'gndwds.mzn': 149848,
#                                 'wlfprc.ghc': 273202},
#                        'lwbqctd': {'dbfbfjjw': {'mfprqmdp.pnl': 29216,
#                                                 'vhvbcmlh.wdf': 17937,
#                                                 'vqzhr.bsl': 87790},
#                                    'qbn': {'bdg': {'crgzcmrt.jlr': 103738,
#                                                    'dwhl.gmw': 179430,
#                                                    'dwhl.ztl': 118482,
#                                                    'gmlqjh': {'wlfprc.rmt': 116934},
#                                                    'phvf': {'dqbjm': {'lvdwvp.mjp': 180654},
#                                                             'vdpnmst': 43516},
#                                                    'zzjwzlrn': 264818},
#                                            'mbzc.qbv': 79958,
#                                            'nsdgz': 218421},
#                                    'qqqfdrst': {'nsdgz.bmt': 58625,
#                                                 'sfrlrc.jtj': 33328},
#                                    'zhzrhzcv': {'dhcfzq': 119179,
#                                                 'gtmphbt': 270185}},
#                        'swjgs.glp': 203538,
#                        'vdpnmst': {'chvtw': 180546,
#                                    'htgbz': {'nsdgz.vlj': 75079},
#                                    'lwdm.snh': 133410,
#                                    'swjgs.glp': 134253},
#                        'wlfprc': 140212,
#                        'wlfprc.vqs': 26253}}}

# %%
# Brute force
def size_of_directory(d: dict):
    size = 0
    for elem in d.values():
        if isinstance(elem, dict):
            size += size_of_directory(elem)
        else:
            size += elem
    return size

# %%
# Problem 1
from collections import Counter
directories = Counter()  # directory names

DIR_SIZE_THRESHOLD = 1e5

n_dirs_below_threshold = 0
sum_size_below_threshold = 0

queue = [("/", filesystem)]
while len(queue) > 0:
    name, directory  = queue.pop()
    directories[name] += 1
    dir_size = size_of_directory(directory)
    if dir_size <= DIR_SIZE_THRESHOLD:
        n_dirs_below_threshold += 1
        sum_size_below_threshold += dir_size
    for name, elem in directory.items():
        if isinstance(elem, dict):
            queue.append((name, elem))

# %%
sum_size_below_threshold
# Out:
# 1447046

# %%
# Problem 2

TOTAL_DISK_SPACE = 70e6
REQUIRED_EMPTY_SPACE = 30e6

dir_sizes = []  # list of (dir size, dir name)

queue = [("/", filesystem)]
while len(queue) > 0:
    name, directory = queue.pop()
    dir_size = size_of_directory(directory)
    dir_sizes.append((dir_size, name))
    
    for name, elem in directory.items():
        if isinstance(elem, dict):
            queue.append((name, elem))
dir_sizes.sort()

# %%
dir_sizes
# Out:
# [(9122, 'dwhl'),
#  (18842, 'pczq'),
#  (19761, 'ltm'),
#  (23604, 'fmqzns'),
#  (29411, 'chvtw'),
#  (35655, 'vbrtv'),
#  (37680, 'cmfz'),
#  (40876, 'dncq'),
#  (42736, 'dqvlqnn'),
#  (44070, 'gbzslwz'),
#  (44070, 'njzvwjh'),
#  (49897, 'wjl'),
#  (54889, 'bpgdn'),
#  (58709, 'mbbvp'),
#  (62849, 'rvgrjsps'),
#  (64480, 'wlfprc'),
#  (67998, 'chvtw'),
#  (75018, 'dwhl'),
#  (75018, 'zrmt'),
#  (75079, 'htgbz'),
#  (78145, 'jvddlfsf'),
#  (79390, 'dwhl'),
#  (84667, 'chvtw'),
#  (85968, 'fgfm'),
#  (91953, 'qqqfdrst'),
#  (97159, 'wlfprc'),
#  (100360, 'glhdqhf'),
#  (103303, 'dwhl'),
#  (115858, 'jqwgwcm'),
#  (116043, 'dwhl'),
#  (116934, 'gmlqjh'),
#  (121465, 'chvtw'),
#  (121465, 'jgzjzvh'),
#  (121465, 'wjq'),
#  (121465, 'zmwmcgcr'),
#  (121863, 'jdzsng'),
#  (121937, 'jbgpgvj'),
#  (124084, 'zqvh'),
#  (124522, 'dwhl'),
#  (127691, 'lmplrbzc'),
#  (127691, 'mmf'),
#  (134943, 'dbfbfjjw'),
#  (135900, 'rll'),
#  (138102, 'hnv'),
#  (138102, 'nbbdv'),
#  (140503, 'dzlv'),
#  (140953, 'fqdzv'),
#  (143769, 'wlfprc'),
#  (149177, 'qdjl'),
#  (159296, 'mgzvqhtr'),
#  (161664, 'ppwm'),
#  (163854, 'wvgj'),
#  (164016, 'frrsl'),
#  (165937, 'thwdjln'),
#  (168263, 'jptp'),
#  (171189, 'wlfprc'),
#  (179811, 'wlfprc'),
#  (180121, 'wlfprc'),
#  (180654, 'dqbjm'),
#  (188613, 'nsdgz'),
#  (191751, 'gwwrhjh'),
#  (191751, 'lvnsvm'),
#  (196534, 'nhtz'),
#  (197043, 'dggm'),
#  (199932, 'bcbgqzj'),
#  (202759, 'crzqrz'),
#  (204248, 'hsjb'),
#  (205962, 'fvfmzg'),
#  (208378, 'nsdgz'),
#  (209990, 'wblwwf'),
#  (213100, 'vztfzgrd'),
#  (222659, 'vdpnmst'),
#  (224170, 'phvf'),
#  (224392, 'lwtrqrqq'),
#  (227959, 'cgstfrbl'),
#  (227959, 'dmcbshg'),
#  (227959, 'fsh'),
#  (231371, 'twfztmq'),
#  (240079, 'qwrh'),
#  (241211, 'chvtw'),
#  (242122, 'mts'),
#  (245482, 'dwhl'),
#  (245705, 'zlh'),
#  (247974, 'zrjzmj'),
#  (253652, 'dwhl'),
#  (267448, 'hfnjf'),
#  (267448, 'vnzvmpmg'),
#  (273982, 'wlfprc'),
#  (276326, 'vdpnmst'),
#  (281944, 'nsdgz'),
#  (283831, 'dwhl'),
#  (283831, 'dwhl'),
#  (283957, 'tbldv'),
#  (287521, 'chvtw'),
#  (297770, 'qzdb'),
#  (307536, 'wlfprc'),
#  (308328, 'pds'),
#  (311994, 'ncmpwvrd'),
#  (332053, 'rdcmr'),
#  (335044, 'chvtw'),
#  (336924, 'qngflrgr'),
#  (345612, 'chvtw'),
#  (365002, 'wlfprc'),
#  (389364, 'zhzrhzcv'),
#  (392294, 'cgrdfzc'),
#  (426517, 'qrmg'),
#  (443516, 'cqv'),
#  (443516, 'vdpnmst'),
#  (468658, 'chvtw'),
#  (468658, 'flzpg'),
#  (468658, 'vhspmg'),
#  (470125, 'wlfprc'),
#  (470125, 'zhfg'),
#  (487171, 'nsdgz'),
#  (489636, 'pwrvqrjc'),
#  (491139, 'hdvdfnw'),
#  (518123, 'nsdgz'),
#  (523288, 'vdpnmst'),
#  (540766, 'gbcqgszh'),
#  (542268, 'wlfprc'),
#  (542620, 'nsjfgmrs'),
#  (560110, 'qwfvql'),
#  (565311, 'dwhl'),
#  (578710, 'hsbg'),
#  (595973, 'vdpnmst'),
#  (630742, 'dwhl'),
#  (654364, 'tgwtvm'),
#  (678422, 'jtbh'),
#  (708275, 'jzhvmj'),
#  (740808, 'lwpbbb'),
#  (787136, 'mzmdjhjq'),
#  (855495, 'bbgbnr'),
#  (868410, 'ztpggl'),
#  (877440, 'llwsnsd'),
#  (920177, 'nsdgz'),
#  (928654, 'wlfprc'),
#  (957187, 'nsdgz'),
#  (964668, 'wlfprc'),
#  (1007572, 'bdg'),
#  (1024076, 'mdvt'),
#  (1108442, 'stqhwh'),
#  (1116394, 'nhmqcpdl'),
#  (1131702, 'fcqfgnvh'),
#  (1232342, 'ttq'),
#  (1305951, 'qbn'),
#  (1336356, 'fnw'),
#  (1380412, 'mvvltrs'),
#  (1397300, 'bfwl'),
#  (1437143, 'vdfw'),
#  (1454218, 'nlnbr'),
#  (1457559, 'cqwh'),
#  (1646706, 'qwjp'),
#  (1747473, 'zfrpc'),
#  (1880592, 'bztjtqg'),
#  (1922211, 'lwbqctd'),
#  (1966727, 'cgbpbw'),
#  (2031063, 'hpfr'),
#  (2527393, 'bpc'),
#  (2804186, 'dwhl'),
#  (3296328, 'gvddj'),
#  (3545109, 'nsdgz'),
#  (4097479, 'vdpnmst'),
#  (4180751, 'wdgzsg'),
#  (4240485, 'zzmgz'),
#  (4663626, 'chvtw'),
#  (6495688, 'tvplqllb'),
#  (6728526, 'fml'),
#  (10131546, 'vfrbjgdm'),
#  (16358912, 'mgnl'),
#  (28574715, 'qjphltd'),
#  (40572957, '/')]

# %%
total_used_space = dir_sizes[-1][0]  # is the max which is of "/"
print(f"{total_used_space=}")

space_to_free = total_used_space - (TOTAL_DISK_SPACE - REQUIRED_EMPTY_SPACE)
print(f"{space_to_free=}")
# Out:
# total_used_space=40572957
# space_to_free=572957.0

# %%
import bisect

idx_item_to_remove = bisect.bisect_left([x[0] for x in dir_sizes], space_to_free)

# %%
dir_sizes[idx_item_to_remove-1:idx_item_to_remove+2]
# Out:
# [(565311, 'dwhl'), (578710, 'hsbg'), (595973, 'vdpnmst')]

# %%
dir_sizes[idx_item_to_remove]
# Out:
# (578710, 'hsbg')

# %%
a = [1,2,3,4,5]

bisect.bisect_left(a, 3.5)
# Out:
# 3

# %%
help(bisect.bisect_left)
# Out:
# Help on built-in function bisect_left in module _bisect:
#
# bisect_left(a, x, lo=0, hi=None)
#     Return the index where to insert item x in list a, assuming a is sorted.
#
#     The return value i is such that all e in a[:i] have e < x, and all e in
#     a[i:] have e >= x.  So if x already appears in the list, i points just
#     before the leftmost x already there.
#
#     Optional args lo (default 0) and hi (default len(a)) bound the
#     slice of a to be searched.
